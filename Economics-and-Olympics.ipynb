# %%
# %load_ext autoreload
# %autoreload 2

from data_tables import *
from visualizations import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
get_medals_all()
# Out:
#                                  Team (IOC code) SG Partcipated  Gold Silver  \
# 0                               Afghanistan(AFG)             14     0      0
# 1                                   Algeria(ALG)             13     5      4
# 2                                 Argentina(ARG)             24    21     25
# 3                                   Armenia(ARM)              6     2      6
# 4                         Australasia(ANZ) [ANZ]              2     3      4
# ..                                           ...            ...   ...    ...
# 148                          Zimbabwe(ZIM) [ZIM]             13     3      4
# 149      Independent Olympic Athletes(IOA) [IOA]              3     1      0
# 150  Independent Olympic Participants(IOP) [IOP]              1     0      1
# 151                        Mixed team(ZZX) [ZZX]              3     8      5
# 152                                       Totals             28  5116   5080
#
# ...

# %%
get_medals_top10()
# Out:
#   Rank              Nation  Gold Silver Bronze Total
# 0    1  United States(USA)  1127    907    794  2828
# 1    2         Russia(RUS)   726    593    591  1910
# 2    3        Germany(GER)   578    589    587  1754
# 3    4  Great Britain(GBR)   274    299    310   883
# 4    5         France(FRA)   248    276    316   840
# 5    6          Italy(ITA)   246    214    241   701
# 6    7          China(CHN)   237    195    176   608
# 7    8         Sweden(SWE)   202    216    234   652
# 8    9         Norway(NOR)   188    174    158   520
# 9   10        Hungary(HUN)   176    149    173   498

# %%
get_GDP_PPP()
# Out:
#     Rank Country/Territory GDP (in millions)
# 0                    World         136713677
# 1      1             China          23523358
# 2      2     United States          21433226
# 3      3             India           9560220
# 4      4             Japan           5504331
# ..   ...               ...               ...
# 188  188             Palau               331
# 189  189          Kiribati               279
# 190  190  Marshall Islands               233
# 191  191             Nauru               152
# 192  192            Tuvalu                52
#
# [193 rows x 3 columns]

# %%
medals = get_medals_all();
GDP = get_GDP_PPP();

plot_GDPvMedals(medals, GDP)

# %%
medals = get_medals_all();
GDP = get_GDP_PPP();

plot_GDPvMedals_noOutliers(medals, GDP)

# %%
countries = []
medals = []
graph_medals(get_medals_all())

# %%
get_IHDI()
# Out:
# [<tr>
# <th colspan="6" style="color:#090;"><span data-sort-value="1.000 !"><b>Very high human development</b></span>
# </th></tr>, <tr>
# <td>1</td>
# <td style="text-align:left"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="372" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/21px-Flag_of_Norway.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/32px-Flag_of_Norway.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/41px-Flag_of_Norway.svg.png 2x" width="21"/> </span><a href="/wiki/Norway" title="Norway">Norway</a></td>
# <td>0.899</td>
# <td>0.957</td>
# <td>6.1</td>
# ...
